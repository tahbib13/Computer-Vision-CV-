# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 28.0 MB/s eta 0:00:00
# ...

# %%
import ultralytics

ultralytics.checks()
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 42.9/112.6 GB disk)

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir RoadSignDetection

# %%
# !ls
# Out:
# RoadSignDetection

# %%
path = "/content/RoadSignDetection"

# %%
import os
os.chdir("/content/RoadSignDetection")

# %%
# %pwd
# Out:
# '/content/RoadSignDetection'

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="yf12pMR1O5dDdiKWRh06")
project = rf.workspace("selfdriving-car-qtywx").project("self-driving-cars-lfjou")
version = project.version(1)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Self-Driving-Cars-1 in yolov8:: 100%|██████████| 8660/8660 [00:01<00:00, 6314.47it/s]

# %%
import os
os.chdir("/content/Self-Driving-Cars-1")

# %%
# !yolo task=detect mode=train model=yolov8n.pt data =data.yaml epochs=10 imgsz=640 batch=16
# Out:
# ...
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# %pwd
# Out:
# '/content/Self-Driving-Cars-1'

# %%
os.chdir("/content")

# %%
# %pwd
# Out:
# '/content'

# %%
# !mkdir ManualTestingData

# %%
BestPath = "/content/Self-Driving-Cars-1/runs/detect/train/weights"

# %%
# !yolo task=detect mode=predict model=$BestPath/best.pt conf=0.25 source = "/content/Test Video 01.mp4" save = True
# Out:
# Traceback (most recent call last):
#   File "/usr/local/bin/yolo", line 8, in <module>
#     sys.exit(entrypoint())
#              ^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/cfg/__init__.py", line 981, in entrypoint
#     model = YOLO(model, task=task)
#             ^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/models/yolo/model.py", line 76, in __init__
#     super().__init__(model=model, task=task, verbose=verbose)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 144, in __init__
#     self._load(model, task=task)
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/engine/model.py", line 283, in _load
#     self.model, self.ckpt = load_checkpoint(weights)
#                             ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/ultralytics/nn/tasks.py", line 1537, in load_checkpoint
# ...

# %%
# !ls /content/Self-Driving-Cars-1/runs/detect/train/weights
# Out:
# best.pt  last.pt

# %%
# !yolo task=detect mode=predict \
model="/content/Self-Driving-Cars-1/runs/detect/train/weights/best.pt" \
conf=0.25 \
source="/content/Test Video 01.mp4" \
save=True
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,008,378 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/421) /content/Test Video 01.mp4: 640x384 (no detections), 66.1ms
# video 1/1 (frame 2/421) /content/Test Video 01.mp4: 640x384 (no detections), 8.0ms
# video 1/1 (frame 3/421) /content/Test Video 01.mp4: 640x384 (no detections), 7.8ms
# video 1/1 (frame 4/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 9.0ms
# video 1/1 (frame 5/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 7.8ms
# video 1/1 (frame 6/421) /content/Test Video 01.mp4: 640x384 (no detections), 7.7ms
# video 1/1 (frame 7/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 12.2ms
# video 1/1 (frame 8/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 7.8ms
# video 1/1 (frame 9/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 8.7ms
# video 1/1 (frame 10/421) /content/Test Video 01.mp4: 640x384 1 Red Light, 8.2ms
# ...

# %%
# !yolo task=detect mode=predict \
model="/content/Self-Driving-Cars-1/runs/detect/train/weights/best.pt" \
conf=0.25 \
source="/content/Test Video 02.mp4" \
save=True
# Out:
# Ultralytics 8.4.51 🚀 Python-3.12.13 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Model summary (fused): 73 layers, 3,008,378 parameters, 0 gradients, 8.1 GFLOPs
#
# video 1/1 (frame 1/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 1 Red Light, 46.4ms
# video 1/1 (frame 2/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 1 Red Light, 10.4ms
# video 1/1 (frame 3/446) /content/Test Video 02.mp4: 640x384 3 Green Lights, 2 Red Lights, 6.3ms
# video 1/1 (frame 4/446) /content/Test Video 02.mp4: 640x384 3 Green Lights, 2 Red Lights, 6.1ms
# video 1/1 (frame 5/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 2 Red Lights, 6.7ms
# video 1/1 (frame 6/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 1 Red Light, 6.3ms
# video 1/1 (frame 7/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 2 Red Lights, 7.0ms
# video 1/1 (frame 8/446) /content/Test Video 02.mp4: 640x384 2 Green Lights, 2 Red Lights, 6.9ms
# ...
