# %% [markdown]
# If you want to create a general object detection project (person, car, dog, cat, bicycle, animals, etc.),
#
# then you do not need to train your own model first.
#
# You can use a pretrained YOLO model directly.
#
# YOLO already knows thousands of common objects from the COCO dataset.

# %% [markdown]
# These models can detect:
#
# Person
#
# Car  Bus  Bicycle
#
# Dog  Cat  Bird
#
# Horse  Cow  Bottle
#
# Chair  Laptop  Phone
#
# and many more.

# %%
from ultralytics import YOLO

# %%
model = YOLO("yolov8n.pt")

# %%
import cv2


# load video
cap = cv2.VideoCapture("Cat and Dog.mp4")

ret = True
# read frames
while ret:
    ret, frame = cap.read()

    if ret:

        # detect objects
        # track objects
        results = model.track(frame, persist=True)

        # plot results
        # cv2.rectangle
        # cv2.putText
        frame_ = results[0].plot()

        # visualize
        cv2.imshow('frame', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break


# release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x352 1 cat, 1 dog, 1 bowl, 1 bed, 1 refrigerator, 205.1ms
# Speed: 18.4ms preprocess, 205.1ms inference, 28.0ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 1 bowl, 117.3ms
# Speed: 5.2ms preprocess, 117.3ms inference, 1.6ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 1 bowl, 120.4ms
# Speed: 6.2ms preprocess, 120.4ms inference, 5.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 1 bowl, 1 bed, 1 refrigerator, 91.4ms
# Speed: 5.7ms preprocess, 91.4ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 1 bowl, 1 refrigerator, 131.1ms
# Speed: 7.5ms preprocess, 131.1ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# 0: 640x352 1 cat, 1 dog, 1 bowl, 1 refrigerator, 208.3ms
# Speed: 7.0ms preprocess, 208.3ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 352)
#
# ...

# %%
import cv2


# load video
cap = cv2.VideoCapture("Chicken.mp4")

ret = True
# read frames
while ret:
    ret, frame = cap.read()

    if ret:

        # detect objects
        # track objects
        results = model.track(frame, persist=True)

        # plot results
        # cv2.rectangle
        # cv2.putText
        frame_ = results[0].plot()

        # visualize
        cv2.imshow('frame', frame_)
        if cv2.waitKey(25) & 0xFF == ord('q'):
            break


# release resources
cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 640x384 2 persons, 2 cows, 98.9ms
# Speed: 5.6ms preprocess, 98.9ms inference, 1.5ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cows, 145.2ms
# Speed: 4.9ms preprocess, 145.2ms inference, 2.6ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cows, 110.7ms
# Speed: 4.9ms preprocess, 110.7ms inference, 1.0ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 cows, 98.9ms
# Speed: 5.2ms preprocess, 98.9ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cows, 95.8ms
# Speed: 3.6ms preprocess, 95.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 2 persons, 2 cows, 95.2ms
# Speed: 3.5ms preprocess, 95.2ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 384)
#
# 0: 640x384 1 person, 2 horses, 2 cows, 79.6ms
# Speed: 5.0ms preprocess, 79.6ms inference, 1.4ms postprocess per image at shape (1, 3, 640, 384)
#
# ...

# %% [markdown]
# # Real Time Object Detection From Webcam

# %%
model = YOLO("yolov8n.pt")

cap = cv2.VideoCapture(0)

while True:
    ret, frame = cap.read()

    results = model(frame)

    annotated_frame = results[0].plot()

    cv2.imshow("Detection", annotated_frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 1 person, 1 bottle, 163.2ms
# Speed: 3.4ms preprocess, 163.2ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 172.1ms
# Speed: 5.1ms preprocess, 172.1ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 166.5ms
# Speed: 6.3ms preprocess, 166.5ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 149.3ms
# Speed: 3.8ms preprocess, 149.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 133.0ms
# Speed: 4.9ms preprocess, 133.0ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 147.1ms
# Speed: 2.5ms preprocess, 147.1ms inference, 3.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 1 person, 1 bottle, 127.2ms
# Speed: 4.2ms preprocess, 127.2ms inference, 1.1ms postprocess per image at shape (1, 3, 480, 640)
# ...
