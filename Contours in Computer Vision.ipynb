# %% [markdown]
# Contours are curves or boundaries that join all continuous points having the same intensity or color.
#
# In simple words:
#
# ➡️ Contours detect the outline/shape of objects in an image.
#
# Used for:
#
# Object detection
#
# Shape recognition
#
# Counting objects
#
# Size measurement
#
# Motion detection
#
# Hand gesture recognition

# %%
import cv2

img = cv2.imread("Bear.jpg")
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

_, thresh = cv2.threshold(gray, 127, 255, cv2.THRESH_BINARY)

contours, hierarchy = cv2.findContours(
    thresh,
    cv2.RETR_EXTERNAL,
    cv2.CHAIN_APPROX_SIMPLE
)

cv2.drawContours(img, contours, -1, (0,255,0), 2)

cv2.imshow("Contours", img)
cv2.waitKey(0)
cv2.destroyAllWindows()

print("Total Objects:", len(contours))
# Out:
# Total Objects: 1747

# %% [markdown]
# # Interview Answer
#
# Contours are boundaries of objects detected in an image.
#
# In OpenCV, contours are used for shape analysis, object detection, measuring area, and tracking objects.
